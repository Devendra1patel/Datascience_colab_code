# %% [markdown]
# <a href="https://colab.research.google.com/github/Devendra1patel/Datascience_colab_code/blob/main/5_(3_feb)2_pandas_advance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/59184  2391558311
# 1     https://github.com/pandas-dev/pandas/pull/59183  2391274591
# 2   https://github.com/pandas-dev/pandas/issues/59182  2390958375
# 3     https://github.com/pandas-dev/pandas/pull/59181  2390906540
# 4     https://github.com/pandas-dev/pandas/pull/59179  2390269605
# 5     https://github.com/pandas-dev/pandas/pull/59178  2389601483
# 6   https://github.com/pandas-dev/pandas/issues/59177  2389277105
# 7     https://github.com/pandas-dev/pandas/pull/59173  2387298263
# 8     https://github.com/pandas-dev/pandas/pull/59172  2387214979
# 9   https://github.com/pandas-dev/pandas/issues/59170  2386867431
# 10  https://github.com/pandas-dev/pandas/issues/59165  2385272154
# 11  https://github.com/pandas-dev/pandas/issues/59164  2385092809
# 12  https://github.com/pandas-dev/pandas/issues/59163  2384575350
# 13  https://github.com/pandas-dev/pandas/issues/59161  2384536291
# 14  https://github.com/pandas-dev/pandas/issues/59160  2384469816
# 15    https://github.com/pandas-dev/pandas/pull/59157  2384264965
# 16    https://github.com/pandas-dev/pandas/pull/59155  2383826075
# 17  https://github.com/pandas-dev/pandas/issues/59154  2383695888
# 18  https://github.com/pandas-dev/pandas/issues/59153  2383186357
# 19    https://github.com/pandas-dev/pandas/pull/59151  2382495796
# 20    https://github.com/pandas-dev/pandas/pull/59150  2382452463
# 21  https://github.com/pandas-dev/pandas/issues/59149  2382258468
# 22    https://github.com/pandas-dev/pandas/pull/59148  2381937929
# 23  https://github.com/pandas-dev/pandas/issues/59147  2381787376
# 24    https://github.com/pandas-dev/pandas/pull/59146  2381587452
# 25    https://github.com/pandas-dev/pandas/pull/59145  2381486098
# 26    https://github.com/pandas-dev/pandas/pull/59143  2381126444
# 27    https://github.com/pandas-dev/pandas/pull/59142  2381079844
# 28    https://github.com/pandas-dev/pandas/pull/59141  2381044496
# 29  https://github.com/pandas-dev/pandas/issues/59140  2381027237
#
#                 node_id  number  \
# 0    I_kwDOAA0YD86OjEin   59184
# 1   PR_kwDOAA0YD850d8At   59183
# 2    I_kwDOAA0YD86OgyEn   59182
# 3   PR_kwDOAA0YD850crUF   59181
# 4   PR_kwDOAA0YD850aikg   59179
# 5   PR_kwDOAA0YD850YRtV   59178
# 6    I_kwDOAA0YD86OaXmx   59177
# 7   PR_kwDOAA0YD850QXhx   59173
# 8   PR_kwDOAA0YD850QFF0   59172
# 9    I_kwDOAA0YD86ORLTn   59170
# 10   I_kwDOAA0YD86OLF1a   59165
# 11   I_kwDOAA0YD86OKaDJ   59164
# 12   I_kwDOAA0YD86OIbt2   59163
# 13   I_kwDOAA0YD86OISLj   59161
# 14   I_kwDOAA0YD86OIB84   59160
# 15  PR_kwDOAA0YD850F-87   59157
# 16  PR_kwDOAA0YD850EfC4   59155
# 17   I_kwDOAA0YD86OFFAQ   59154
# 18   I_kwDOAA0YD86ODIm1   59153
# 19  PR_kwDOAA0YD85z_7Ea   59151
# 20  PR_kwDOAA0YD85z_ymy   59150
# 21   I_kwDOAA0YD86N_mEk   59149
# 22  PR_kwDOAA0YD85z-L-p   59148
# 23   I_kwDOAA0YD86N9zDw   59147
# 24  PR_kwDOAA0YD85z9A-C   59146
# 25  PR_kwDOAA0YD85z8rj0   59145
# 26  PR_kwDOAA0YD85z7e5U   59143
# 27  PR_kwDOAA0YD85z7VTG   59142
# 28  PR_kwDOAA0YD85z7NeM   59141
# 29   I_kwDOAA0YD86N65el   59140
#
#                                                 title  ... closed_at  \
# 0   BUG: Timestamp.asm8 has different behavior dep...  ...       NaT
# 1   BUG: Fix .dt.microsecond accessor for pyarrow-...  ...       NaT
# 2   ENH: check_dtype='equiv' for assert_frame_equa...  ...       NaT
# 3                    update algo.take to solve #59177  ...       NaT
# 4    DEPR: group by one element list gets scalar keys  ...       NaT
# 5   PERF: Don't create a CategoricalIndex._engine ...  ...       NaT
# 6   BUG: pd.api.extensions.take does not accept Nu...  ...       NaT
# 7   TST: Added script to enforce usage of match ar...  ...       NaT
# 8   REF: Move methods in core/reshape/util.py to w...  ...       NaT
# 9                                               BUG:   ...       NaT
# 10  ENH: In pd.cut(), allow bins='auto' (leveragin...  ...       NaT
# 11  DOC: Sort the pandas API reference navbar in a...  ...       NaT
# 12  ENH: Add Option to Include Array Offset as Mul...  ...       NaT
# 13  DEPR: `keep_default_dates` and  `convert_dates...  ...       NaT
# 14  VOTE: Voting issue for PDEP-14: Dedicated stri...  ...       NaT
# 15               header, update in basic.rst M #59130  ...       NaT
# 16  Avoid empty lines with spaces to be transforme...  ...       NaT
# 17  BUG: `.dt.microsecond` for pyarrow-backed Seri...  ...       NaT
# 18  BUG: Enlarging multilevel index fails if one o...  ...       NaT
# 19                  Add a New form of using pd.eval()  ...       NaT
# 20                     Add "N / A" to `STR_NA_VALUES`  ...       NaT
# 21                                 database is locked  ...       NaT
# 22  BUG: Fix difference functionality for Period I...  ...       NaT
# 23                  BUG: read_html returns empty list  ...       NaT
# 24  DOC: Fixed validate_title_capitalization warni...  ...       NaT
# 25                         DataFrame.eval error fixed  ...       NaT
# 26  CLN: enforced the deprecation of strings 'H', ...  ...       NaT
# 27     ENH: Allow adjust=False when times is provided  ...       NaT
# 28                     REF: Make concat not stateful.  ...       NaT
# 29  ENH: Query function to have a star * for all c...  ...       NaT
#
#    author_association active_lock_reason  \
# 0              MEMBER                NaN
# 1              MEMBER                NaN
# 2                NONE                NaN
# 3         CONTRIBUTOR                NaN
# 4         CONTRIBUTOR                NaN
# 5              MEMBER                NaN
# 6                NONE                NaN
# 7                NONE                NaN
# 8              MEMBER                NaN
# 9                NONE                NaN
# 10               NONE                NaN
# 11               NONE                NaN
# 12               NONE                NaN
# 13             MEMBER                NaN
# 14             MEMBER                NaN
# 15               NONE                NaN
# 16               NONE                NaN
# 17             MEMBER                NaN
# 18               NONE                NaN
# 19               NONE                NaN
# 20        CONTRIBUTOR                NaN
# 21               NONE                NaN
# 22               NONE                NaN
# 23               NONE                NaN
# 24               NONE                NaN
# 25               NONE                NaN
# 26        CONTRIBUTOR                NaN
# 27               NONE                NaN
# 28             MEMBER                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   - [x] closes #59154(Replace xxxx with the GitH...
# 2   ### Feature Type\n\n- [ ] Adding new functiona...
# 3   - [x] closes #59177\r\n- [x] [Tests added and ...
# 4   - [x] closes #58858\r\n\r\nchanged the behavio...
# 5                                                None
# 6   ### Pandas version checks\n\n- [X] I have chec...
# 7   xref #58290 \r\n\r\nAdded a script called `enf...
# 8   2 unit tests were removed since `cartesian_pro...
# 9   ### Pandas version checks\r\n\r\n- [X] I have ...
# 10  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  ### Feature Type\n\n- [X] Adding new functiona...
# 13  `read_json` has `convert_dates`, `keep_default...
# 14  ### PDEP number and title\r\n\r\nPDEP-14: Dedi...
# 15  closes #59130\r\n![Screenshot 2024-07-01 22000...
# 16  - [x] closes #59147  (Replace xxxx with the Gi...
# 17  ### Pandas version checks\r\n\r\n- [X] I have ...
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  - [x] closes #56491\r\n- [x] Tests added and p...
# 20  This is a value that I just came across in som...
# 21  ### Research\n\n- [X] I have searched the [[pa...
# 22  - [x] closes #58971\r\n- [x] [Tests added and ...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  …snew doc files. Sorted exceptions list alphab...
# 25  - [x] closes #59062  (Replace xxxx with the Gi...
# 26  Enforced deprecation of uppercase strings ‘H’,...
# 27  - [ x ] closes [#54328](https://github.com/pan...
# 28  All the logic used to be held in a `_Concatena...
# 29  ### Feature Type\n\n- [ ] Adding new functiona...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   NaN
# 3                       NaN           NaN   0.0
# 4                       NaN           NaN   1.0
# 5                       NaN           NaN   0.0
# 6                       NaN           NaN   NaN
# 7                       NaN           NaN   0.0
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   NaN
# 10                      NaN           NaN   NaN
# 11                      NaN           NaN   NaN
# 12                      NaN           NaN   NaN
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   0.0
# 16                      NaN           NaN   0.0
# 17                      NaN           NaN   NaN
# 18                      NaN           NaN   NaN
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   0.0
# 21                      NaN           NaN   NaN
# 22                      NaN           NaN   0.0
# 23                      NaN           NaN   NaN
# 24                      NaN           NaN   0.0
# 25                      NaN           NaN   0.0
# 26                      NaN           NaN   0.0
# 27                      NaN           NaN   0.0
# 28                      NaN           NaN   0.0
# 29                      NaN           NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23                                                NaN
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 30 columns]

# %%
import requests
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df = data.json()

# %%
len(df)
# Out:
# 30

# %%
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59184',
#   'id': 2391558311,
#   'node_id': 'I_kwDOAA0YD86OjEin',
#   'number': 59184,
#   'title': 'BUG: Timestamp.asm8 has different behavior depending on how it was constructed',
#   'user': {'login': 'Aloqeely',
#    'id': 52792999,
#    'node_id': 'MDQ6VXNlcjUyNzkyOTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52792999?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aloqeely',
#    'html_url': 'https://github.com/Aloqeely',
#    'followers_url': 'https://api.github.com/users/Aloqeely/followers',
#    'following_url': 'https://api.github.com/users/Aloqeely/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aloqeely/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aloqeely/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aloqeely/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aloqeely/orgs',
#    'repos_url': 'https://api.github.com/users/Aloqeely/repos',
#    'events_url': 'https://api.github.com/users/Aloqeely/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aloqeely/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-04T23:50:34Z',
#   'updated_at': '2024-07-04T23:50:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nIn [2]: ts1 = pd.Timestamp(year=2023, month=1, day=1, hour=10, second=15)\r\n\r\nIn [3]: ts2 = pd.Timestamp(\'2023-01-01 10:00:15\') #  ts1 and ts2 are equal\r\n\r\nIn [4]: np.int64(ts1.asm8)\r\nOut[4]: 1672567215000000\r\n\r\nIn [5]: np.int64(ts2.asm8)\r\nOut[5]: 1672567215\n```\n\n\n### Issue Description\n\nIn the [timestamp.asm8 doc](https://pandas.pydata.org/docs/dev/reference/api/pandas.Timestamp.asm8.html) it states "Return numpy datetime64 format in nanoseconds.", but, it has different (wrong) behavior when I construct the timestamp from a string, returning in milliseconds format. Any thoughts @MarcoGorelli?\n\n### Expected Behavior\n\nI would expect `np.int64(ts2.asm8)` to be equal to `1672567215000000`\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : 1b2d39cbfc3db9520e0f5455a4eb3da0f569fa0f\r\npython                : 3.12.1\r\npython-bits           : 64\r\nOS                    : Windows\r\nOS-release            : 10\r\nVersion               : 10.0.19045\r\nmachine               : AMD64\r\nprocessor             : AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : English_United States.1252\r\n\r\npandas                : 2.2.2\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.9.0.post0\r\npip                   : 24.0\r\nCython                : 3.0.10\r\nsphinx                : 7.3.7\r\nIPython               : 8.23.0\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.3\r\nblosc                 : None\r\nbottleneck            : 1.3.8\r\nfastparquet           : 2024.2.0\r\nfsspec                : 2024.3.1\r\nhtml5lib              : 1.1\r\nhypothesis            : 6.100.1\r\ngcsfs                 : 2024.3.1\r\njinja2                : 3.1.4\r\nlxml.etree            : 5.2.1\r\nmatplotlib            : 3.8.4\r\nnumba                 : 0.59.1\r\nnumexpr               : 2.10.0\r\nodfpy                 : None\r\nopenpyxl              : 3.1.2\r\npsycopg2              : 2.9.9\r\npymysql               : 1.4.6\r\npyarrow               : 16.1.0\r\npyreadstat            : 1.2.7\r\npytest                : 8.1.1\r\npython-calamine       : None\r\npyxlsb                : 1.0.10\r\ns3fs                  : 2024.3.1\r\nscipy                 : 1.13.0\r\nsqlalchemy            : 2.0.29\r\ntables                : 3.9.2\r\ntabulate              : 0.9.0\r\nxarray                : 2024.5.0\r\nxlrd                  : 2.0.1\r\nxlsxwriter            : 3.2.0\r\nzstandard             : 0.22.0\r\ntzdata                : 2024.1\r\nqtpy                  : None\r\npyqt5                 : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59184/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59183',
#   'id': 2391274591,
#   'node_id': 'PR_kwDOAA0YD850d8At',
#   'number': 59183,
#   'title': 'BUG: Fix .dt.microsecond accessor for pyarrow-backed Series',
#   'user': {'login': 'Aloqeely',
#    'id': 52792999,
#    'node_id': 'MDQ6VXNlcjUyNzkyOTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52792999?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aloqeely',
#    'html_url': 'https://github.com/Aloqeely',
#    'followers_url': 'https://api.github.com/users/Aloqeely/followers',
#    'following_url': 'https://api.github.com/users/Aloqeely/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aloqeely/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aloqeely/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aloqeely/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aloqeely/orgs',
#    'repos_url': 'https://api.github.com/users/Aloqeely/repos',
#    'events_url': 'https://api.github.com/users/Aloqeely/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aloqeely/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-04T17:43:23Z',
#   'updated_at': '2024-07-04T17:43:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59183',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59183',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59183.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59183.patch',
#    'merged_at': None},
#   'body': '- [x] closes #59154(Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59183/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59182',
#   'id': 2390958375,
#   'node_id': 'I_kwDOAA0YD86OgyEn',
#   'number': 59182,
#   'title': "ENH: check_dtype='equiv' for assert_frame_equal in unit testing",
#   'user': {'login': 'levaphenyl',
#    'id': 29597341,
#    'node_id': 'MDQ6VXNlcjI5NTk3MzQx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29597341?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/levaphenyl',
#    'html_url': 'https://github.com/levaphenyl',
#    'followers_url': 'https://api.github.com/users/levaphenyl/followers',
#    'following_url': 'https://api.github.com/users/levaphenyl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/levaphenyl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/levaphenyl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/levaphenyl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/levaphenyl/orgs',
#    'repos_url': 'https://api.github.com/users/levaphenyl/repos',
#    'events_url': 'https://api.github.com/users/levaphenyl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/levaphenyl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-04T14:05:06Z',
#   'updated_at': '2024-07-04T14:05:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nMy test fails because the data cast and expected data have slightly different types, like `int32` vs. `int64`. \r\nI don\'t want to use `assert_frame_equal(df1, df2, check_dtype=False)` because it does not check the data type at all, which is bad.\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n\r\na = pd.DataFrame({\'Int\': [1, 2, 3], \'Float\': [0.57, 0.179, 0.213]})  # Automatic type casting\r\n# Force 32-bit\r\nb = a.copy()\r\nb[\'Int\'] = b[\'Int\'].astype(\'int32\')\r\nb[\'Float\'] = b[\'Float\'].astype(\'float32\')\r\n# Force 64-bit\r\nc = a.copy()\r\nc[\'Int\'] = c[\'Int\'].astype(\'int64\')\r\nc[\'Float\'] = c[\'Float\'].astype(\'float64\')\r\ntry:\r\n    pd.testing.assert_frame_equal(b, c)\r\n    print(\'Success\')\r\nexcept AssertionError as err:\r\n    print(err)\r\n```\r\n\r\ngives\r\n\r\n```\r\nAttributes of DataFrame.iloc[:, 0] (column name="Int") are different\r\n\r\nAttribute "dtype" are different\r\n[left]:  int32\r\n[right]: int64\r\n```\n\n### Feature Description\n\nSomething like `assert_frame_equal(df1, df2, check_dtype=\'equiv\')` would be handy but it does not work because the function uses the hard check of [`assert_attr_equal`](https://github.com/pandas-dev/pandas/blob/2.2.x/pandas/_testing/asserters.py#L386) under the hood.\r\n\r\nIt means changing the logic to either have a soft attribute check in `assert_attr_equal`, or call a new function if the `check_dtype` is set to `\'equiv\'`.\n\n### Alternative Solutions\n\nI added a workaround function to my unit tests, which casts the data type of one DataFrame to the other when the types are similar (int, float).\r\n\r\n```python\r\ndef assert_frame_equiv(left: pd.DataFrame, right: pd.DataFrame) -> None:\r\n    """Convert equivalent data types to same before comparing.\r\n\r\n    Parameters\r\n    ----------\r\n    left : DataFrame\r\n        First DataFrame to compare.\r\n    right : DataFrame\r\n        Second DataFrame to compare.\r\n\r\n    Raises\r\n    ------\r\n    AssertionError\r\n        If the DataFrames are different.\r\n    """\r\n    # First, check that the columns are the same.\r\n    pd.testing.assert_index_equal(left.columns, right.columns, check_order=False)\r\n    # Knowing columns names are the same, cast the same data type if equivalent.\r\n    for col_name in left.columns:\r\n        lcol = left[col_name]\r\n        rcol = right[col_name]\r\n        if (\r\n            (pd.api.types.is_integer_dtype(lcol) and pd.api.types.is_integer_dtype(rcol))\r\n            or (pd.api.types.is_float_dtype(lcol) and pd.api.types.is_float_dtype(rcol))\r\n        ):\r\n            left[col_name] = lcol.astype(rcol.dtype)\r\n\r\n    return pd.testing.assert_frame_equal(left, right, check_like=True)\r\n```\n\n### Additional Context\n\nAdapted from my [answer on SO](https://stackoverflow.com/a/78707389/8289769).\r\n\r\nThanks for making `pandas`!',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59182/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59181',
#   'id': 2390906540,
#   'node_id': 'PR_kwDOAA0YD850crUF',
#   'number': 59181,
#   'title': 'update algo.take to solve #59177',
#   'user': {'login': 'mutricyl',
#    'id': 118692416,
#    'node_id': 'U_kgDOBxMaQA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118692416?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mutricyl',
#    'html_url': 'https://github.com/mutricyl',
#    'followers_url': 'https://api.github.com/users/mutricyl/followers',
#    'following_url': 'https://api.github.com/users/mutricyl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mutricyl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mutricyl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mutricyl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mutricyl/orgs',
#    'repos_url': 'https://api.github.com/users/mutricyl/repos',
#    'events_url': 'https://api.github.com/users/mutricyl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mutricyl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-07-04T13:39:20Z',
#   'updated_at': '2024-07-05T07:28:31Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59181',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59181',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59181.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59181.patch',
#    'merged_at': None},
#   'body': '- [x] closes #59177\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59181/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59179',
#   'id': 2390269605,
#   'node_id': 'PR_kwDOAA0YD850aikg',
#   'number': 59179,
#   'title': 'DEPR: group by one element list gets scalar keys',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-04T08:29:34Z',
#   'updated_at': '2024-07-04T08:32:42Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59179',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59179',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59179.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59179.patch',
#    'merged_at': None},
#   'body': '- [x] closes #58858\r\n\r\nchanged the behavior: group `keys` to be `1-tuples` instead of `scalar` when grouping with a `length-1 list`',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59179/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59178',
#   'id': 2389601483,
#   'node_id': 'PR_kwDOAA0YD850YRtV',
#   'number': 59178,
#   'title': "PERF: Don't create a CategoricalIndex._engine in __contains__ if categories are RangeIndex",
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-03T22:31:21Z',
#   'updated_at': '2024-07-04T00:34:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59178',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59178',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59178.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59178.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59178/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59177',
#   'id': 2389277105,
#   'node_id': 'I_kwDOAA0YD86OaXmx',
#   'number': 59177,
#   'title': 'BUG: pd.api.extensions.take does not accept NumpyExtensionArray',
#   'user': {'login': 'andrewgsavage',
#    'id': 13157776,
#    'node_id': 'MDQ6VXNlcjEzMTU3Nzc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13157776?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andrewgsavage',
#    'html_url': 'https://github.com/andrewgsavage',
#    'followers_url': 'https://api.github.com/users/andrewgsavage/followers',
#    'following_url': 'https://api.github.com/users/andrewgsavage/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/andrewgsavage/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/andrewgsavage/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/andrewgsavage/subscriptions',
#    'organizations_url': 'https://api.github.com/users/andrewgsavage/orgs',
#    'repos_url': 'https://api.github.com/users/andrewgsavage/repos',
#    'events_url': 'https://api.github.com/users/andrewgsavage/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/andrewgsavage/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Non-arithmetic algos: value_counts, factorize, sorting, isin, clip, shift, diff'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'mutricyl',
#    'id': 118692416,
#    'node_id': 'U_kgDOBxMaQA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118692416?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mutricyl',
#    'html_url': 'https://github.com/mutricyl',
#    'followers_url': 'https://api.github.com/users/mutricyl/followers',
#    'following_url': 'https://api.github.com/users/mutricyl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mutricyl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mutricyl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mutricyl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mutricyl/orgs',
#    'repos_url': 'https://api.github.com/users/mutricyl/repos',
#    'events_url': 'https://api.github.com/users/mutricyl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mutricyl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'mutricyl',
#     'id': 118692416,
#     'node_id': 'U_kgDOBxMaQA',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/118692416?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mutricyl',
#     'html_url': 'https://github.com/mutricyl',
#     'followers_url': 'https://api.github.com/users/mutricyl/followers',
#     'following_url': 'https://api.github.com/users/mutricyl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mutricyl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mutricyl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mutricyl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mutricyl/orgs',
#     'repos_url': 'https://api.github.com/users/mutricyl/repos',
#     'events_url': 'https://api.github.com/users/mutricyl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mutricyl/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-07-03T19:13:18Z',
#   'updated_at': '2024-07-04T13:27:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd \r\nimport numpy as np\r\n\r\narr = pd.arrays.NumpyExtensionArray(np.array([1,2,3]))\r\npd.api.extensions.take(arr,[2])\r\n\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "D:\\mambaforge\\envs\\test_py300\\Lib\\site-packages\\pandas\\core\\algorithms.py", line 1166, in take\r\n    raise TypeError(\r\nTypeError: pd.api.extensions.take requires a numpy.ndarray, ExtensionArray, Index, or Series, got NumpyExtensionArray.\n```\n\n\n### Issue Description\n\nI\'d expect NumpyExtensionArray to be considered an ExtensionArray, so compatable with pd.api.extensions.take.\n\n### Expected Behavior\n\nreturn\r\n```\r\n<NumpyExtensionArray>\r\n[2]\r\nLength: 1, dtype: int32\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nReplace this line with the output of pd.show_versions()\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59177/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59173',
#   'id': 2387298263,
#   'node_id': 'PR_kwDOAA0YD850QXhx',
#   'number': 59173,
#   'title': 'TST: Added script to enforce usage of match argument for tm.assert_produces_warning ',
#   'user': {'login': 'chaarvii',
#    'id': 49508554,
#    'node_id': 'MDQ6VXNlcjQ5NTA4NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49508554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaarvii',
#    'html_url': 'https://github.com/chaarvii',
#    'followers_url': 'https://api.github.com/users/chaarvii/followers',
#    'following_url': 'https://api.github.com/users/chaarvii/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chaarvii/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chaarvii/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chaarvii/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chaarvii/orgs',
#    'repos_url': 'https://api.github.com/users/chaarvii/repos',
#    'events_url': 'https://api.github.com/users/chaarvii/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chaarvii/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-02T22:56:09Z',
#   'updated_at': '2024-07-04T20:42:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59173',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59173',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59173.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59173.patch',
#    'merged_at': None},
#   'body': "xref #58290 \r\n\r\nAdded a script called `enforce_match_arg_in_assert_produces_warning.py` which checks that all usages of tm.assert_produces_warning make use of the `match` argument. This is done to ensure that users are always displayed the correct warning message. Uses of `tm.assert_produces_warning(None)` have been excluded as no warning is produced in this case. \r\n\r\nFurthermore, to ensure that the existing code doesn't fail the `pre-commit` stage, all files that currently do not use the match argument have been excluded. \r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59173/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59172',
#   'id': 2387214979,
#   'node_id': 'PR_kwDOAA0YD850QFF0',
#   'number': 59172,
#   'title': 'REF: Move methods in core/reshape/util.py to where they are used',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 1011,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-07-02T22:24:06Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-07-02T21:41:58Z',
#   'updated_at': '2024-07-03T16:46:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59172',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59172',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59172.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59172.patch',
#    'merged_at': None},
#   'body': '2 unit tests were removed since `cartesian_product` now strictly operates on `list[np.ndarray]` (i.e. `MultiIndex.codes`) and the unit tests were testing `Index` inputs',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59172/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59170',
#   'id': 2386867431,
#   'node_id': 'I_kwDOAA0YD86ORLTn',
#   'number': 59170,
#   'title': 'BUG: ',
#   'user': {'login': 'seanv507',
#    'id': 3305775,
#    'node_id': 'MDQ6VXNlcjMzMDU3NzU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3305775?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seanv507',
#    'html_url': 'https://github.com/seanv507',
#    'followers_url': 'https://api.github.com/users/seanv507/followers',
#    'following_url': 'https://api.github.com/users/seanv507/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/seanv507/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/seanv507/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/seanv507/subscriptions',
#    'organizations_url': 'https://api.github.com/users/seanv507/orgs',
#    'repos_url': 'https://api.github.com/users/seanv507/repos',
#    'events_url': 'https://api.github.com/users/seanv507/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/seanv507/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-02T18:14:35Z',
#   'updated_at': '2024-07-02T18:16:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nz3 = pd.DataFrame({"a":[10], "b":[2], "c": [1]}).set_index(["a", "b"])\r\nmaturities = list(range(100))\r\nz4 = z3.reindex(maturities,level=1)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nI create a 1 row dataframe with multiindex\r\nI reindex on a single level, and I expect all values in the new index to be in the new dataframe.\r\ninstead, the same dataframe is returned.\r\n\r\nthe same happens with more than a single row.\r\n\r\nIf I use a 1d index, or apply to the columns, I get a 100 row/column dataframe as expected\r\n\r\n### Expected Behavior\r\n\r\n```\r\nexpected_output = pd.DataFrame({"a":10, "b": range(100), "c": np.nan}).set_index(["a", "b"])\r\nexpected_output.loc[(10,2), "c"]=1\r\n\r\nexpected_output.head()\r\n#          c\r\n# a  b     \r\n# 10 0  NaN\r\n#    1  NaN\r\n#    2  1.0\r\n#    3  NaN\r\n#    4  NaN\r\n```\r\n### Installed Versions\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e86ed377639948c64c429059127bcf5b359ab6be\r\npython              : 3.11.5.final.0\r\npython-bits         : 64\r\nOS                  : Darwin\r\nOS-release          : 23.5.0\r\nVersion             : Darwin Kernel Version 23.5.0: Wed May  1 20:19:05 PDT 2024; root:xnu-10063.121.3~5/RELEASE_ARM64_T8112\r\nmachine             : arm64\r\nprocessor           : arm\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : en_US.UTF-8\r\nLOCALE              : en_US.UTF-8\r\n\r\npandas              : 2.1.1\r\nnumpy               : 1.26.0\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 68.2.2\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : None\r\nhypothesis          : None\r\nsphinx              : 7.2.6\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etree          : None\r\nhtml5lib            : None\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.15.0\r\npandas_datareader   : None\r\nbs4                 : None\r\nbottleneck          : None\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : None\r\ngcsfs               : None\r\nmatplotlib          : 3.8.0\r\nnumba               : None\r\nnumexpr             : None\r\nodfpy               : None\r\nopenpyxl            : None\r\npandas_gbq          : None\r\npyarrow             : None\r\npyreadstat          : None\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.2\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : None\r\nxarray              : None\r\nxlrd                : None\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59170/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59165',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59165/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59165/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59165/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59165',
#   'id': 2385272154,
#   'node_id': 'I_kwDOAA0YD86OLF1a',
#   'number': 59165,
#   'title': "ENH: In pd.cut(), allow bins='auto' (leveraging `np.histogram_bin_edges`)",
#   'user': {'login': 'Hari-Shankar-Karthik',
#    'id': 143477305,
#    'node_id': 'U_kgDOCI1KOQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/143477305?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hari-Shankar-Karthik',
#    'html_url': 'https://github.com/Hari-Shankar-Karthik',
#    'followers_url': 'https://api.github.com/users/Hari-Shankar-Karthik/followers',
#    'following_url': 'https://api.github.com/users/Hari-Shankar-Karthik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Hari-Shankar-Karthik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Hari-Shankar-Karthik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Hari-Shankar-Karthik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Hari-Shankar-Karthik/orgs',
#    'repos_url': 'https://api.github.com/users/Hari-Shankar-Karthik/repos',
#    'events_url': 'https://api.github.com/users/Hari-Shankar-Karthik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Hari-Shankar-Karthik/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1639305834,
#     'node_id': 'MDU6TGFiZWwxNjM5MzA1ODM0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/cut',
#     'name': 'cut',
#     'color': '9aace2',
#     'default': False,
#     'description': 'cut, qcut'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'chaarvii',
#    'id': 49508554,
#    'node_id': 'MDQ6VXNlcjQ5NTA4NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49508554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaarvii',
#    'html_url': 'https://github.com/chaarvii',
#    'followers_url': 'https://api.github.com/users/chaarvii/followers',
#    'following_url': 'https://api.github.com/users/chaarvii/following{/other_user}',
# ...
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-06-28T20:21:03Z',
#   'updated_at': '2024-07-04T07:55:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59143',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59143',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59143.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59143.patch',
#    'merged_at': None},
#   'body': "Enforced deprecation of uppercase strings ‘H’, ‘BH’, ‘CBH’ for offsets frequencies, resolution abbreviations, and units  in favor of 'h', 'bh', 'cbh'\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59143/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59143/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59142',
#   'id': 2381079844,
#   'node_id': 'PR_kwDOAA0YD85z7VTG',
#   'number': 59142,
#   'title': 'ENH: Allow adjust=False when times is provided',
#   'user': {'login': 'tserrao',
#    'id': 15620622,
#    'node_id': 'MDQ6VXNlcjE1NjIwNjIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15620622?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tserrao',
#    'html_url': 'https://github.com/tserrao',
#    'followers_url': 'https://api.github.com/users/tserrao/followers',
#    'following_url': 'https://api.github.com/users/tserrao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tserrao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tserrao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tserrao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tserrao/orgs',
#    'repos_url': 'https://api.github.com/users/tserrao/repos',
#    'events_url': 'https://api.github.com/users/tserrao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tserrao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-06-28T19:51:43Z',
#   'updated_at': '2024-07-02T18:32:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59142',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59142',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59142.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59142.patch',
#    'merged_at': None},
#   'body': '- [ x ] closes [#54328](https://github.com/pandas-dev/pandas/issues/54328) (partially)\r\n- [ x ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ x ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ x  ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ x ] Added an entry in the latest `doc/source/whatsnew/v3.0.0.rst` \r\n\r\nThis change enables EWMA to be calculated recursively ("infinite history", i.e. `adjust=False`) for irregular-interval time series. Previously `new_wt` was held constant in the ewm run loop, but now `new_wt` is updated each step through the series under the narrow condition that `adjust=False` and `com=1`.\r\n\r\nThere may be a more elegant expression that will generalize to `com` values different than one, but using `1 - old_wt` works nicely if `halflife` is the only provided decay parameter since we are guaranteed `com=1`. The additional parameter restrictions to force this condition seem acceptable since there is already [some restriction](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.ewm.html) on decay parameters.\r\n\r\n> Exactly one of `com`, `span`, `halflife`, or `alpha` must be provided if `times` is not provided. If `times` is provided, `halflife` and one of `com`, `span` or `alpha` may be provided.\r\n\r\nFWIW I confirmed that results match polars and @azmyrajab\'s nice [test function](https://github.com/pandas-dev/pandas/issues/54328#issuecomment-2072214710):\r\n\r\n```\r\nema_no_adjust = ema_test(vals, dt_seconds, half_life=half_life_seconds)[-1]\r\nema_no_adjust_pl = ema_polars(df["val"].rename_axis(index="ts").rename("val"), half_life,\r\n                              by="ts").select("val")[-1].item()\r\n\r\nprint(ema_no_adjust)\r\nprint(ema_no_adjust_pl)\r\nprint(df.ewm(halflife=half_life, times=id, adjust=False).mean().iloc[-1][\'val\'])\r\n\r\n0.2062994740159002\r\n0.2062994740159002\r\n0.2062994740159002\r\n```\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59142/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59141',
#   'id': 2381044496,
#   'node_id': 'PR_kwDOAA0YD85z7NeM',
#   'number': 59141,
#   'title': 'REF: Make concat not stateful.',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 1011,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-07-02T22:24:06Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-06-28T19:25:18Z',
#   'updated_at': '2024-07-03T16:46:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/59141',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/59141',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/59141.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/59141.patch',
#    'merged_at': None},
#   'body': "All the logic used to be held in a `_Concatenator` class. The statefullness wasn't really needed since `concat` is a one-shot method so broke it out into its functions",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59141/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/59140',
#   'id': 2381027237,
#   'node_id': 'I_kwDOAA0YD86N65el',
#   'number': 59140,
#   'title': 'ENH: Query function to have a star * for all columns',
#   'user': {'login': 'dstone42',
#    'id': 97193062,
#    'node_id': 'U_kgDOBcsMZg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97193062?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dstone42',
#    'html_url': 'https://github.com/dstone42',
#    'followers_url': 'https://api.github.com/users/dstone42/followers',
#    'following_url': 'https://api.github.com/users/dstone42/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dstone42/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dstone42/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dstone42/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dstone42/orgs',
#    'repos_url': 'https://api.github.com/users/dstone42/repos',
#    'events_url': 'https://api.github.com/users/dstone42/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dstone42/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-06-28T19:14:37Z',
#   'updated_at': '2024-06-28T19:14:37Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI have a data frame that has a large number of columns that have positive numeric values except the last 4 columns. There are some rows with missing data, but in this dataset, they denote that by using a very large negative number. My plan was to use the query function to filter the rows to only those that have values greater than or equal to zero in every numeric column. \n\n### Feature Description\n\nI wish the query function would let me do something like this df.query('* >= 0') the star * representing all columns. Better yet, would be if I could use star but subtract the columns to be excluded from that like df.query('* -state -county >= 0').\n\n### Alternative Solutions\n\nWhat I am going to do is loop through the columns of the data frame and query on each one using a variable and exclude those non-numeric from my list. Like this:\r\n\r\n```column_list = df.columns\r\ncolumn_list.remove('state')\r\ncolumn_list.remove('county')\r\n\r\nfor column in column_list:\r\n    df = df.query('@column >= 0')\r\n```\n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59140/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
for i in range(len(df)):
    print(df[i]['user']['node_id'])
# Out:
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjI5NTk3MzQx
# U_kgDOBxMaQA
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEzMTU3Nzc2
# MDQ6VXNlcjQ5NTA4NTU0
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjMzMDU3NzU=
# U_kgDOCI1KOQ
# MDQ6VXNlcjUyMDk4NQ==
# U_kgDOB3Ju0A
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwMjA0OTY=
# U_kgDOCiVf4A
# MDQ6VXNlcjQzNTA5Njk5
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjI1NTI4NzAx
# U_kgDOBfToYQ
# MDQ6VXNlcjEwODIwNjg2
# MDQ6VXNlcjQ1OTEyNTYx
# MDQ6VXNlcjg2NjA0NTQ=
# MDQ6VXNlcjQ3NTk4MjE5
# MDQ6VXNlcjcwNzI2NzE=
# U_kgDOBz8XbQ
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjE1NjIwNjIy
# MDQ6VXNlcjEwNjQ3MDgy
# U_kgDOBcsMZg

# %%
df = pd.DataFrame(df, columns = ['user', 'timeline_url'])

# %%
df
# Out:
#                                                  user  \
# 0   {'login': 'Aloqeely', 'id': 52792999, 'node_id...
# 1   {'login': 'Aloqeely', 'id': 52792999, 'node_id...
# 2   {'login': 'levaphenyl', 'id': 29597341, 'node_...
# 3   {'login': 'mutricyl', 'id': 118692416, 'node_i...
# 4   {'login': 'natmokval', 'id': 91160475, 'node_i...
# 5   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   {'login': 'andrewgsavage', 'id': 13157776, 'no...
# 7   {'login': 'chaarvii', 'id': 49508554, 'node_id...
# 8   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 9   {'login': 'seanv507', 'id': 3305775, 'node_id'...
# 10  {'login': 'Hari-Shankar-Karthik', 'id': 143477...
# 11  {'login': 'jeropaul', 'id': 520985, 'node_id':...
# 12  {'login': 'chelsea-lin', 'id': 124939984, 'nod...
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 15  {'login': 'BadakalaYashwanth', 'id': 170221536...
# 16  {'login': 'ritwizsinha', 'id': 43509699, 'node...
# 17  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 18  {'login': 'micky-gee', 'id': 25528701, 'node_i...
# 19  {'login': 'PedroVerardo', 'id': 99936353, 'nod...
# 20  {'login': 'NickCrews', 'id': 10820686, 'node_i...
# 21  {'login': 'Happiness-in-Danger', 'id': 4591256...
# 22  {'login': 'TiffL', 'id': 8660454, 'node_id': '...
# 23  {'login': 'Fredrik-M', 'id': 47598219, 'node_i...
# 24  {'login': 'kajor3k', 'id': 7072671, 'node_id':...
# 25  {'login': 'Riyazul555', 'id': 121575277, 'node...
# 26  {'login': 'natmokval', 'id': 91160475, 'node_i...
# 27  {'login': 'tserrao', 'id': 15620622, 'node_id'...
# 28  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 29  {'login': 'dstone42', 'id': 97193062, 'node_id...
#
#                                          timeline_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
# df.to_csv('json_info.csv')

# %%
#Solving the dataset
#this is taitanic dataset

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
from google.colab import files

# %%
files.download('json_info.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() #numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[df.columns[df.dtypes == 'object']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[df.dtypes[df.dtypes != 'object'].index].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.columns[df.dtypes != 'object']].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
# df.numeric.describe()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df[10:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 45                           Rogers, Mr. William John    male   NaN      0
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 60                              Sirayanian, Mr. Orsen    male  22.0      0
# 65                           Moubarek, Master. Gerios    male   NaN      1
# 70                         Jenkin, Mr. Stephen Curnow    male  32.0      0
# 75                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 80                               Waelens, Mr. Achille    male  22.0      0
# 85  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 90                               Christmann, Mr. Emil    male  29.0      0
# 95                        Shorney, Mr. Charles Joseph    male   NaN      0
#
#     Parch           Ticket     Fare  Cabin Embarked
# 10      1          PP 9549  16.7000     G6        S
# 15      0           248706  16.0000    NaN        S
# 20      0           239865  26.0000    NaN        S
# 25      5           347077  31.3875    NaN        S
# 30      0         PC 17601  27.7208    NaN        C
# 35      0           113789  52.0000    NaN        S
# 40      0             7546   9.4750    NaN        S
# 45      0  S.C./A.4. 23567   8.0500    NaN        S
# 50      1          3101295  39.6875    NaN        S
# 55      0            19947  35.5000    C52        S
# 60      0             2669   7.2292    NaN        C
# 65      1             2661  15.2458    NaN        C
# 70      0       C.A. 33111  10.5000    NaN        S
# 75      0           348123   7.6500  F G73        S
# 80      0           345767   9.0000    NaN        S
# 85      0          3101278  15.8500    NaN        S
# 90      0           343276   8.0500    NaN        S
# 95      0           374910   8.0500    NaN        S

# %%
df['new_col'] = "Anjali"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col
# 0        0         A/5 21171   7.2500   NaN        S  Anjali
# 1        0          PC 17599  71.2833   C85        C  Anjali
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali
# 3        0            113803  53.1000  C123        S  Anjali
# 4        0            373450   8.0500   NaN        S  Anjali
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S  Anjali
# 887      0            112053  30.0000   B42        S  Anjali
# 888      2        W./C. 6607  23.4500   NaN        S  Anjali
# 889      0            111369  30.0000  C148        C  Anjali
# 890      0            370376   7.7500   NaN        Q  Anjali
#
# [891 rows x 13 columns]

# %%
df['family'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1        0          PC 17599  71.2833   C85        C  Anjali       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3        0            113803  53.1000  C123        S  Anjali       1
# 4        0            373450   8.0500   NaN        S  Anjali       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S  Anjali       0
# 887      0            112053  30.0000   B42        S  Anjali       0
# 888      2        W./C. 6607  23.4500   NaN        S  Anjali       3
# 889      0            111369  30.0000  C148        C  Anjali       0
# 890      0            370376   7.7500   NaN        Q  Anjali       0
#
# [891 rows x 14 columns]

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1        0          PC 17599  71.2833   C85        C  Anjali       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3        0            113803  53.1000  C123        S  Anjali       1
# 4        0            373450   8.0500   NaN        S  Anjali       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S  Anjali       0
# 887      0            112053  30.0000   B42        S  Anjali       0
# 888      2        W./C. 6607  23.4500   NaN        S  Anjali       3
# 889      0            111369  30.0000  C148        C  Anjali       0
# 890      0            370376   7.7500   NaN        Q  Anjali       0
#
# [891 rows x 14 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  family
# 0      0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1      0          PC 17599  71.2833   C85        C  Anjali       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3      0            113803  53.1000  C123        S  Anjali       1
# 4      0            373450   8.0500   NaN        S  Anjali       0

# %%
#Q. How many passengers are less than 5 years old

df[df['Age'] < 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 193          194         1       2                Navratil, Master. Michel M
# 205          206         0       3                Strom, Miss. Telma Matilda
# 261          262         1       3         Asplund, Master. Edvin Rojj Felix
# 297          298         0       1              Allison, Miss. Helen Loraine
# 305          306         1       1            Allison, Master. Hudson Trevor
# 340          341         1       2            Navratil, Master. Edmond Roger
# 348          349         1       3    Coutts, Master. William Loch "William"
# 374          375         0       3                Palsson, Miss. Stina Viola
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 386          387         0       3           Goodwin, Master. Sidney Leonard
# 407          408         1       2            Richards, Master. William Rowe
# 445          446         1       1                 Dodge, Master. Washington
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 530          531         1       2                  Quick, Miss. Phyllis May
# 618          619         1       2               Becker, Miss. Marion Louise
# 642          643         0       3             Skoog, Miss. Margit Elizabeth
# 644          645         1       3                    Baclini, Miss. Eugenie
# 691          692         1       3                        Karun, Miss. Manca
# 750          751         1       2                         Wells, Miss. Joan
# 755          756         1       2                 Hamalainen, Master. Viljo
# 788          789         1       3                Dean, Master. Bertram Vere
# 803          804         1       3           Thomas, Master. Assad Alexander
# 824          825         0       3              Panula, Master. Urho Abraham
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 869          870         1       3           Johnson, Master. Harold Theodor
#
#         Sex   Age  SibSp  Parch           Ticket      Fare    Cabin Embarked  \
# 7      male  2.00      3      1           349909   21.0750      NaN        S
# 10   female  4.00      1      1          PP 9549   16.7000       G6        S
# 16     male  2.00      4      1           382652   29.1250      NaN        Q
# 43   female  3.00      1      2    SC/Paris 2123   41.5792      NaN        C
# 63     male  4.00      3      2           347088   27.9000      NaN        S
# 78     male  0.83      0      2           248738   29.0000      NaN        S
# 119  female  2.00      4      2           347082   31.2750      NaN        S
# 164    male  1.00      4      1          3101295   39.6875      NaN        S
# 171    male  4.00      4      1           382652   29.1250      NaN        Q
# 172  female  1.00      1      1           347742   11.1333      NaN        S
# 183    male  1.00      2      1           230136   39.0000       F4        S
# 184  female  4.00      0      2           315153   22.0250      NaN        S
# 193    male  3.00      1      1           230080   26.0000       F2        S
# 205  female  2.00      0      1           347054   10.4625       G6        S
# 261    male  3.00      4      2           347077   31.3875      NaN        S
# 297  female  2.00      1      2           113781  151.5500  C22 C26        S
# 305    male  0.92      1      2           113781  151.5500  C22 C26        S
# 340    male  2.00      1      1           230080   26.0000       F2        S
# 348    male  3.00      1      1       C.A. 37671   15.9000      NaN        S
# 374  female  3.00      3      1           349909   21.0750      NaN        S
# 381  female  1.00      0      2             2653   15.7417      NaN        C
# 386    male  1.00      5      2          CA 2144   46.9000      NaN        S
# 407    male  3.00      1      1            29106   18.7500      NaN        S
# 445    male  4.00      0      2            33638   81.8583      A34        S
# 469  female  0.75      2      1             2666   19.2583      NaN        C
# 479  female  2.00      0      1          3101298   12.2875      NaN        S
# 530  female  2.00      1      1            26360   26.0000      NaN        S
# 618  female  4.00      2      1           230136   39.0000       F4        S
# 642  female  2.00      3      2           347088   27.9000      NaN        S
# 644  female  0.75      2      1             2666   19.2583      NaN        C
# 691  female  4.00      0      1           349256   13.4167      NaN        C
# 750  female  4.00      1      1            29103   23.0000      NaN        S
# 755    male  0.67      1      1           250649   14.5000      NaN        S
# 788    male  1.00      1      2        C.A. 2315   20.5750      NaN        S
# 803    male  0.42      0      1             2625    8.5167      NaN        C
# 824    male  2.00      4      1          3101295   39.6875      NaN        S
# 827    male  1.00      0      2  S.C./PARIS 2079   37.0042      NaN        C
# 831    male  0.83      1      1            29106   18.7500      NaN        S
# 850    male  4.00      4      2           347082   31.2750      NaN        S
# 869    male  4.00      1      1           347742   11.1333      NaN        S
#
#     new_col  family
# 7    Anjali       4
# 10   Anjali       2
# 16   Anjali       5
# 43   Anjali       3
# 63   Anjali       5
# 78   Anjali       2
# 119  Anjali       6
# 164  Anjali       5
# 171  Anjali       5
# 172  Anjali       2
# 183  Anjali       3
# 184  Anjali       2
# 193  Anjali       2
# 205  Anjali       1
# 261  Anjali       6
# 297  Anjali       3
# 305  Anjali       3
# 340  Anjali       2
# 348  Anjali       2
# 374  Anjali       4
# 381  Anjali       2
# 386  Anjali       7
# 407  Anjali       2
# 445  Anjali       2
# 469  Anjali       3
# 479  Anjali       1
# 530  Anjali       2
# 618  Anjali       3
# 642  Anjali       5
# 644  Anjali       3
# 691  Anjali       1
# 750  Anjali       2
# 755  Anjali       2
# 788  Anjali       3
# 803  Anjali       1
# 824  Anjali       5
# 827  Anjali       2
# 831  Anjali       2
# 850  Anjali       6
# 869  Anjali       2

# %%
len(df[df['Age'] < 5])
# Out:
# 40

# %%
#no of passenger >18

len(df[df['Age'] > 18])
# Out:
# 575

# %%
#how many passengers are less than 18 years old

len(df) - len(df[df['Age'] > 18])
# Out:
# 316

# %%
len(df[df['Age'] <= 18]) #missing value in age column
# Out:
# 139

# %%
#Q. How many passengers have paid less than avg fare

df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[df['Fare']<df['Fare'].mean()]

# %%
len(df[df['Fare'] > df['Fare'].mean()])
# Out:
# 211

# %%
#How many passengers paid 0 fare

list(df[df['Fare'] == 0].Name)
# Out:
# ['Leonard, Mr. Lionel',
#  'Harrison, Mr. William',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Johnson, Mr. William Cahoone Jr',
#  'Cunningham, Mr. Alfred Fleming',
#  'Campbell, Mr. William',
#  'Frost, Mr. Anthony Wood "Archie"',
#  'Johnson, Mr. Alfred',
#  'Parr, Mr. William Henry Marsh',
#  'Watson, Mr. Ennis Hastings',
#  'Knight, Mr. Robert J',
#  'Andrews, Mr. Thomas Jr',
#  'Fry, Mr. Richard',
#  'Reuchlin, Jonkheer. John George']

# %%
#Qhow many passengers are male and female
len(df[df['Sex'] == "male"])
# Out:
# 577

# %%
len(df[df['Sex'] == "female"])
# Out:
# 314

# %%
df['Sex'].value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
#Q how many passengers of class 1

df[df['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked new_col  family
# 1        0  PC 17599  71.2833          C85        C  Anjali       1
# 3        0    113803  53.1000         C123        S  Anjali       1
# 6        0     17463  51.8625          E46        S  Anjali       0
# 11       0    113783  26.5500         C103        S  Anjali       0
# 23       0    113788  35.5000           A6        S  Anjali       0
# ..     ...       ...      ...          ...      ...     ...     ...
# 871      1     11751  52.5542          D35        S  Anjali       2
# 872      0       695   5.0000  B51 B53 B55        S  Anjali       0
# 879      1     11767  83.1583          C50        C  Anjali       1
# 887      0    112053  30.0000          B42        S  Anjali       0
# 889      0    111369  30.0000         C148        C  Anjali       0
#
# [216 rows x 14 columns]

# %%
#How many passengers survived


df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 1        0          PC 17599  71.2833   C85        C  Anjali       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3        0            113803  53.1000  C123        S  Anjali       1
# 8        2            347742  11.1333   NaN        S  Anjali       2
# 9        0            237736  30.0708   NaN        C  Anjali       1
# ..     ...               ...      ...   ...      ...     ...     ...
# 875      0              2667   7.2250   NaN        C  Anjali       0
# 879      1             11767  83.1583   C50        C  Anjali       1
# 880      1            230433  26.0000   NaN        S  Anjali       1
# 887      0            112053  30.0000   B42        S  Anjali       0
# 889      0            111369  30.0000  C148        C  Anjali       0
#
# [342 rows x 14 columns]

# %%
df['Survived'].value_counts(normalize = True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
#How many females paid more than avg fare


df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[(df['Sex'] == 'female') & (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch         Ticket      Fare Cabin Embarked new_col  family
# 1        0       PC 17599   71.2833   C85        C  Anjali       1
# 3        0         113803   53.1000  C123        S  Anjali       1
# 31       0       PC 17569  146.5208   B78        C  Anjali       1
# 43       2  SC/Paris 2123   41.5792   NaN        C  Anjali       3
# 52       0       PC 17572   76.7292   D33        C  Anjali       1
# ..     ...            ...       ...   ...      ...     ...     ...
# 853      1       PC 17592   39.4000   D28        S  Anjali       1
# 856      1          36928  164.8667   NaN        S  Anjali       2
# 863      2       CA. 2343   69.5500   NaN        S  Anjali      10
# 871      1          11751   52.5542   D35        S  Anjali       2
# 879      1          11767   83.1583   C50        C  Anjali       1
#
# [104 rows x 14 columns]

# %%
#Q how many passengers are male or who paid greater than avg fare >>or
#Qhow many male passenger paid more than avg >>and
df[(df['Sex'] == 'male') | (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# 6    male  54.0      0      0            17463   51.8625          E46
# 23   male  28.0      0      0           113788   35.5000           A6
# 27   male  19.0      3      2            19950  263.0000  C23 C25 C27
# 34   male  28.0      1      0         PC 17604   82.1708          NaN
# 35   male  42.0      1      0           113789   52.0000          NaN
# ..    ...   ...    ...    ...              ...       ...          ...
# 827  male   1.0      0      2  S.C./PARIS 2079   37.0042          NaN
# 838  male  32.0      0      0             1601   56.4958          NaN
# 846  male   NaN      8      2         CA. 2343   69.5500          NaN
# 848  male  28.0      0      1           248727   33.0000          NaN
# 867  male  31.0      0      0         PC 17590   50.4958          A24
#
#     Embarked new_col  family
# 6          S  Anjali       0
# 23         S  Anjali       0
# 27         S  Anjali       5
# 34         C  Anjali       1
# 35         S  Anjali       1
# ..       ...     ...     ...
# 827        C  Anjali       2
# 838        S  Anjali       0
# 846        S  Anjali      10
# 848        S  Anjali       1
# 867        S  Anjali       0
#
# [107 rows x 14 columns]

# %%
np.mean(df['Fare'])
# Out:
# 32.204207968574636

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df['Fare'])
# Out:
# 0.0

# %%
#who are the passengers who paid maximum fare
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# Q. How many passenger have parch greater than 3
# Q. How many passenger who survived paid the maximum fare
# Q. How many passengers who didnt survived was from class 1
# Q. How many passengers are having children(<5 years old)

# %%
#Access df rows #implicit index>internal/integer index and explicit index/named>>define
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# 95                        Shorney, Mr. Charles Joseph    male   NaN      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
# 97                    Greenfield, Mr. William Bertram    male  23.0      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 99                                  Kantor, Mr. Sinai    male  34.0      1
#
#     Parch            Ticket     Fare    Cabin Embarked new_col  family
# 0       0         A/5 21171   7.2500      NaN        S  Anjali       1
# 1       0          PC 17599  71.2833      C85        C  Anjali       1
# 2       0  STON/O2. 3101282   7.9250      NaN        S  Anjali       0
# 3       0            113803  53.1000     C123        S  Anjali       1
# 4       0            373450   8.0500      NaN        S  Anjali       0
# ..    ...               ...      ...      ...      ...     ...     ...
# 95      0            374910   8.0500      NaN        S  Anjali       0
# 96      0          PC 17754  34.6542       A5        C  Anjali       0
# 97      1          PC 17759  63.3583  D10 D12        C  Anjali       1
# 98      1            231919  23.0000      NaN        S  Anjali       1
# 99      0            244367  26.0000      NaN        S  Anjali       1
#
# [100 rows x 14 columns]

# %%
df.iloc[0:2] #start from 0 and go to 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_col  family
# 0      0  A/5 21171   7.2500   NaN        S  Anjali       1
# 1      0   PC 17599  71.2833   C85        C  Anjali       1

# %%
df.loc[0:2] #give me the rows whose name is 0, 1, 2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  family
# 0      0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1      0          PC 17599  71.2833   C85        C  Anjali       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0

# %%
#loc will go with named indexes, iloc will go with inbuilt index
df.iloc[0:2, ['Name', 'Sex', 'Age']] #it will throw an error, why?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[136], line 2
#       1 #loc will go with named indexes, iloc will go with inbuilt index
# ----> 2 df.iloc[0:2, ['Name', 'Sex', 'Age']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1477, in _iLocIndexer._validate_key(self, key, axis)
#    1475 # check that the key has a numeric dtype
#    1476 if not is_numeric_dtype(arr.dtype):
# -> 1477     raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1479 # check that the key does not exceed the maximum size of the index
#    1480 if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
#
# IndexError: .iloc requires numeric indexers, got ['Name' 'Sex' 'Age']

# %%
df.loc[0:2, ['Name', 'Sex', 'Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1        0          PC 17599  71.2833   C85        C  Anjali       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3        0            113803  53.1000  C123        S  Anjali       1
# 4        0            373450   8.0500   NaN        S  Anjali       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S  Anjali       0
# 887      0            112053  30.0000   B42        S  Anjali       0
# 888      2        W./C. 6607  23.4500   NaN        S  Anjali       3
# 889      0            111369  30.0000  C148        C  Anjali       0
# 890      0            370376   7.7500   NaN        Q  Anjali       0
#
# [891 rows x 14 columns]

# %%
df.iloc[0:2, 3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df['Name'][2:5]), index = ['a', 'b', 'c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]))

# %%
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1 #series or dataframe doesnt work with +
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
s.append(s1)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# 0                                Moran, Mr. James
# 1                         McCarthy, Mr. Timothy J
# 2                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S  Anjali       1
# 1        0          PC 17599  71.2833   C85        C  Anjali       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Anjali       0
# 3        0            113803  53.1000  C123        S  Anjali       1
# 4        0            373450   8.0500   NaN        S  Anjali       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S  Anjali       0
# 887      0            112053  30.0000   B42        S  Anjali       0
# 888      2        W./C. 6607  23.4500   NaN        S  Anjali       3
# 889      0            111369  30.0000  C148        C  Anjali       0
# 890      0            370376   7.7500   NaN        Q  Anjali       0
#
# [891 rows x 14 columns]

# %%
df.drop('PassengerId', axis = 1, inplace=True) #row>>axis=0, axis = 1>>columns

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#     new_col  family
# 0    Anjali       1
# 1    Anjali       1
# 2    Anjali       0
# 3    Anjali       1
# 4    Anjali       0
# ..      ...     ...
# 886  Anjali       0
# 887  Anjali       0
# 888  Anjali       3
# 889  Anjali       0
# 890  Anjali       0
#
# [891 rows x 13 columns]

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S  Anjali
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Anjali
# 3    35.0      1      0            113803  53.1000  C123        S  Anjali
# 4    35.0      0      0            373450   8.0500   NaN        S  Anjali
# 5     NaN      0      0            330877   8.4583   NaN        Q  Anjali
# ..    ...    ...    ...               ...      ...   ...      ...     ...
# 886  27.0      0      0            211536  13.0000   NaN        S  Anjali
# 887  19.0      0      0            112053  30.0000   B42        S  Anjali
# 888   NaN      1      2        W./C. 6607  23.4500   NaN        S  Anjali
# 889  26.0      0      0            111369  30.0000  C148        C  Anjali
# 890  32.0      0      0            370376   7.7500   NaN        Q  Anjali
#
#      family
# 0         1
# 2         0
# 3         1
# 4         0
# 5         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [890 rows x 13 columns]

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S  Anjali
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Anjali
# 3    35.0      1      0            113803  53.1000  C123        S  Anjali
# 4    35.0      0      0            373450   8.0500   NaN        S  Anjali
# 5     NaN      0      0            330877   8.4583   NaN        Q  Anjali
# ..    ...    ...    ...               ...      ...   ...      ...     ...
# 886  27.0      0      0            211536  13.0000   NaN        S  Anjali
# 887  19.0      0      0            112053  30.0000   B42        S  Anjali
# 888   NaN      1      2        W./C. 6607  23.4500   NaN        S  Anjali
# 889  26.0      0      0            111369  30.0000  C148        C  Anjali
# 890  32.0      0      0            370376   7.7500   NaN        Q  Anjali
#
#      family
# 0         1
# 2         0
# 3         1
# 4         0
# 5         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [890 rows x 13 columns]

# %%
df.set_index('Name', inplace = True) #time series data>>you will be making date time column as index

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
#                                               SibSp  Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                           1      0         A/5 21171
# Heikkinen, Miss. Laina                            0      0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0            113803
# Allen, Mr. William Henry                          0      0            373450
# Moran, Mr. James                                  0      0            330877
# ...                                             ...    ...               ...
# Montvila, Rev. Juozas                             0      0            211536
# Graham, Miss. Margaret Edith                      0      0            112053
# Johnston, Miss. Catherine Helen "Carrie"          1      2        W./C. 6607
# Behr, Mr. Karl Howell                             0      0            111369
# Dooley, Mr. Patrick                               0      0            370376
#
#                                                  Fare Cabin Embarked new_col  \
# Name
# Braund, Mr. Owen Harris                        7.2500   NaN        S  Anjali
# Heikkinen, Miss. Laina                         7.9250   NaN        S  Anjali
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123        S  Anjali
# Allen, Mr. William Henry                       8.0500   NaN        S  Anjali
# Moran, Mr. James                               8.4583   NaN        Q  Anjali
# ...                                               ...   ...      ...     ...
# Montvila, Rev. Juozas                         13.0000   NaN        S  Anjali
# Graham, Miss. Margaret Edith                  30.0000   B42        S  Anjali
# Johnston, Miss. Catherine Helen "Carrie"      23.4500   NaN        S  Anjali
# Behr, Mr. Karl Howell                         30.0000  C148        C  Anjali
# Dooley, Mr. Patrick                            7.7500   NaN        Q  Anjali
#
#                                               family
# Name
# Braund, Mr. Owen Harris                            1
# Heikkinen, Miss. Laina                             0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# Allen, Mr. William Henry                           0
# Moran, Mr. James                                   0
# ...                                              ...
# Montvila, Rev. Juozas                              0
# Graham, Miss. Margaret Edith                       0
# Johnston, Miss. Catherine Helen "Carrie"           3
# Behr, Mr. Karl Howell                              0
# Dooley, Mr. Patrick                                0
#
# [890 rows x 12 columns]

# %%
df.loc['Allen, Mr. William Henry']
# Out:
# Survived         0
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# new_col     Anjali
# family           0
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.iloc[3]
# Out:
# Survived         0
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# new_col     Anjali
# family           0
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.head()
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
#
#                                               SibSp  Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                           1      0         A/5 21171
# Heikkinen, Miss. Laina                            0      0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0            113803
# Allen, Mr. William Henry                          0      0            373450
# Moran, Mr. James                                  0      0            330877
#
#                                                  Fare Cabin Embarked new_col  \
# Name
# Braund, Mr. Owen Harris                        7.2500   NaN        S  Anjali
# Heikkinen, Miss. Laina                         7.9250   NaN        S  Anjali
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123        S  Anjali
# Allen, Mr. William Henry                       8.0500   NaN        S  Anjali
# Moran, Mr. James                               8.4583   NaN        Q  Anjali
#
#                                               family
# Name
# Braund, Mr. Owen Harris                            1
# Heikkinen, Miss. Laina                             0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# Allen, Mr. William Henry                           0
# Moran, Mr. James                                   0

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S  Anjali
# 1    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Anjali
# 2    35.0      1      0            113803  53.1000  C123        S  Anjali
# 3    35.0      0      0            373450   8.0500   NaN        S  Anjali
# 4     NaN      0      0            330877   8.4583   NaN        Q  Anjali
# ..    ...    ...    ...               ...      ...   ...      ...     ...
# 885  27.0      0      0            211536  13.0000   NaN        S  Anjali
# 886  19.0      0      0            112053  30.0000   B42        S  Anjali
# 887   NaN      1      2        W./C. 6607  23.4500   NaN        S  Anjali
# 888  26.0      0      0            111369  30.0000  C148        C  Anjali
# 889  32.0      0      0            370376   7.7500   NaN        Q  Anjali
#
#      family
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ..      ...
# 885       0
# 886       0
# 887       3
# 888       0
# 889       0
#
# [890 rows x 13 columns]

# %%
#make dataframe is dictionary
d = {"key1": [2, 3, 4, 5],
    "key2": [4, 5, 6, 7],
    "key3": [2, 3, 4, 5]}

# %%
d
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 4, 5]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
#make dataframe is dictionary
d = {"key1": (2, 3, 4, 5),
    "key2": (4, 5, 6, 7),
    "key3": (2, 3, 4, 5)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.dtypes
# Out:
# taxonomy_id    object
# name           object
# parent_id      object
# parent_name    object
# dtype: object

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(axis = 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis = 1) #for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
df1.fillna("missing_value_here>lalalalalala", inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name  \
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
#                            parent_id                      parent_name
# 0    missing_value_here>lalalalalala  missing_value_here>lalalalalala
# 1                                101                        Emergency
# 2                                101                        Emergency
# 3                             101-02                   Emergency Cash
# 4                             101-02                   Emergency Cash
# ..                               ...                              ...
# 285                           111-01             Advocacy & Legal Aid
# 286                              111                            Legal
# 287                              111                            Legal
# 288                              111                            Legal
# 289                              111                            Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S  Anjali
# 1    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Anjali
# 2    35.0      1      0            113803  53.1000  C123        S  Anjali
# 3    35.0      0      0            373450   8.0500   NaN        S  Anjali
# 4     NaN      0      0            330877   8.4583   NaN        Q  Anjali
# ..    ...    ...    ...               ...      ...   ...      ...     ...
# 885  27.0      0      0            211536  13.0000   NaN        S  Anjali
# 886  19.0      0      0            112053  30.0000   B42        S  Anjali
# 887   NaN      1      2        W./C. 6607  23.4500   NaN        S  Anjali
# 888  26.0      0      0            111369  30.0000  C148        C  Anjali
# 889  32.0      0      0            370376   7.7500   NaN        Q  Anjali
#
#      family
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ..      ...
# 885       0
# 886       0
# 887       3
# 888       0
# 889       0
#
# [890 rows x 13 columns]

# %%
#Q what is the average fare paid by people who survived?
#groupby >> https://www.w3resource.com/python-exercises/pandas/groupby/index.php

# %%
df.groupby('Survived').mean(numeric_only=True) #for recent pandas version

# %%
df.groupby('Survived').mean()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#             Pclass        Age     SibSp     Parch       Fare    family
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.883424
# 1         1.953079  28.310277  0.472141  0.466276  48.328288  0.938416

# %%
df.groupby('Survived').mean()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\123491824.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Survived').max()
#                                  Name  Pclass   Sex   Age  SibSp  Parch  \
# Survived
# 0         van Melkebeke, Mr. Philemon       3  male  74.0      8      6
# 1             de Mulder, Mr. Theodore       3  male  80.0      4      5
#
#              Ticket      Fare new_col  family
# Survived
# 0         WE/P 5735  263.0000  Anjali      10
# 1         WE/P 5735  512.3292  Anjali       6

# %%
df.groupby('Survived').min()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\2003144291.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby('Survived').min()
#                                       Name  Pclass     Sex   Age  SibSp  \
# Survived
# 0                      Abbing, Mr. Anthony       1  female  1.00      0
# 1         Abbott, Mrs. Stanton (Rosa Hunt)       1  female  0.42      0
#
#           Parch  Ticket  Fare new_col  family
# Survived
# 0             0  110413   0.0  Anjali       0
# 1             0  110152   0.0  Anjali       0

# %%
df.groupby('Survived').sum()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\351563020.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').sum()
#           Pclass       Age  SibSp  Parch        Fare  family
# Survived
# 0           1390  12985.50    304    181  12142.7199     485
# 1            666   8181.67    161    159  16479.9461     320

# %%
df.groupby('Survived').mean(numeric_only=True)
# Out:
#             Pclass        Age     SibSp     Parch       Fare    family
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.883424
# 1         1.953079  28.310277  0.472141  0.466276  48.328288  0.938416

# %%
df.groupby('Survived').mean()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#             Pclass        Age     SibSp     Parch       Fare    family
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.883424
# 1         1.953079  28.310277  0.472141  0.466276  48.328288  0.938416

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                 Age  \
#           count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ...  Fare           family                                \
#                mean  ...   75%       max  count      mean       std  min  25%
# Survived             ...
# 0         30.626179  ...  26.0  263.0000  549.0  0.883424  1.830669  0.0  0.0
# 1         28.310277  ...  57.0  512.3292  341.0  0.938416  1.187814  0.0  0.0
#
#
#           50%  75%   max
# Survived
# 0         0.0  1.0  10.0
# 1         1.0  2.0   6.0
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').aggregate([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23656\2251198093.py:1: FutureWarning: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'new_col'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Survived').aggregate([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
#          Pclass                                                  Age        \
#             min max      mean median count       std       var   min   max
# Survived
# 0             1   3  2.531876    3.0   549  0.735805  0.541409  1.00  74.0
# 1             1   3  1.953079    2.0   341  0.863047  0.744851  0.42  80.0
#
#                      ...  Fare                         family                \
#                mean  ... count        std          var    min max      mean
# Survived             ...
# 0         30.626179  ...   549  31.388207   985.219509      0  10  0.883424
# 1         28.310277  ...   341  66.683277  4446.659477      0   6  0.938416
#
#
#          median count       std       var
# Survived
# 0           0.0   549  1.830669  3.351349
# 1           1.0   341  1.187814  1.410902
#
# [2 rows x 42 columns]

# %%
#groupby with two columns
#Q. Total people for each sex, pclass

df1.groupby(['Sex', 'Pclass'])['Survived'].sum()
# Out:
# (549, 13)
# Sex     Pclass
# female  1         0
#         2         0
#         3         0
# male    1         0
#         2         0
#         3         0
# Name: Survived, dtype: int64

# %%
#To convert the result to dataframe
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df.dtypes
# Out:
# Name         object
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# new_col      object
# family        int64
# dtype: object
